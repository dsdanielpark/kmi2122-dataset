# %% [markdown]
# # KMI2122 Dataset

# %% [markdown]
# ## How to Cite
# If you extend or use this work, please cite the paper where it was introduced:
# ```
# Data provided by The Korean Statistical Information Service(KOSIS), "KMI-2122" dataset, accessed from the 'kmi2122-dataset' repository on GitHub (https://github.com/DSDanielPark/kmi2122-dataset) on {Data Citation Date}
# ```
#
# Please use this badge.
# ```
# ![kmi2122-dataset](https://img.shields.io/badge/pypi-kmi2122-blue)
# ```

# %% [markdown]
# !pip install kmi2122

# %%
import kmi2122_dataset as kd

# %% [markdown]
# # 1. Whole dataset Load

# %%
raw_dataset = kd.Dataset()

# %% [markdown]
# # 2. Get DataFrame and dict containing information of columnms.

# %%
kmi = kd.KMI2122()
df = kmi.get_df()
print(df.head())
# Out:
#       date  table0_col1  table0_col2  table0_col3  table0_col4  table0_col5  \
# 0  2021.01         20.0   11049986.0     552499.0     888681.0          1.0
# 1  2021.02         18.0   13514324.0     750796.0    1436213.0          2.0
# 2  2021.03         22.0   23348772.0    1061308.0    1709217.0          3.0
# 3  2021.04         22.0   21866924.0     993951.0    1392981.0          4.0
# 4  2021.05         19.0   27578307.0    1451490.0    2429891.0          5.0
#
#    table0_col6  table0_col7  table0_col8  table0_col9  ...  table9_col8  \
# 0         29.0     337475.0          1.0         14.0  ...          1.0
# 1         24.0     406729.0          2.0         15.0  ...          2.0
# 2          9.0     626974.0          3.0         16.0  ...          3.0
# 3         29.0     691186.0          4.0         12.0  ...          4.0
# 4         12.0     897260.0          5.0         26.0  ...          5.0
#
#    table9_col9  table9_col10  table9_col11  table9_col12  table9_col13  \
# 0          4.0   842145507.0    42107275.0    64852458.0           1.0
# 1          1.0   582788279.0    32377127.0    36545188.0           2.0
# 2         25.0   576095115.0    26186142.0    30933708.0           3.0
# 3         30.0   620427545.0    28201252.0    32105459.0           4.0
# 4         24.0   482488286.0    25394120.0    33446338.0           5.0
#
#    table9_col14  table9_col15  table9_col16  table9_col17
# 0          11.0    34960432.0           1.0          25.0
# 1          24.0    29211084.0           2.0          10.0
# 2           9.0    22397746.0           3.0          15.0
# 3          28.0    23944191.0           4.0           5.0
# 4          12.0    21183749.0           5.0          24.0
#
# [5 rows x 2593 columns]

# %%
col_dict = dict(kmi.column_info())
print(col_dict)
# Out:
# {'table0_date': '거래실적_시점', 'table0_col1': '거래실적_매매일수 (일)', 'table0_col2': '거래실적_거래량', 'table0_col3': '거래실적_거래량.1', 'table0_col4': '거래실적_거래량.2', 'table0_col5': '거래실적_거래량.3', 'table0_col6': '거래실적_거래량.4', 'table0_col7': '거래실적_거래량.5', 'table0_col8': '거래실적_거래량.6', 'table0_col9': '거래실적_거래량.7', 'table0_col10': '거래실적_거래대금', 'table0_col11': '거래실적_거래대금.1', 'table0_col12': '거래실적_거래대금.2', 'table0_col13': '거래실적_거래대금.3', 'table0_col14': '거래실적_거래대금.4', 'table0_col15': '거래실적_거래대금.5', 'table0_col16': '거래실적_거래대금.6', 'table0_col17': '거래실적_거래대금.7', 'table1_date': '투자자별거래실적_시점', 'table1_col1': '투자자별거래실적_총거래량', 'table1_col2': '투자자별거래실적_총거래량.1', 'table1_col3': '투자자별거래실적_총거래량.2', 'table1_col4': '투자자별거래실적_금융투자', 'table1_col5': '투자자별거래실적_금융투자.1', 'table1_col6': '투자자별거래실적_금융투자.2', 'table1_col7': '투자자별거래실적_보험', 'table1_col8': '투자자별거래실적_보험.1', 'table1_col9': '투자자별거래실적_보험.2', 'table1_col10': '투자자별거래실적_투신', 'table1_col11': '투자자별거래실적_투신.1', 'table1_col12': '투자자별거래실적_투신.2', 'table1_col13': '투자자별거래실적_사모', 'table1_col14': '투자자별거래실적_사모.1', 'table1_col15': '투자자별거래실적_사모.2', 'table1_col16': '투자자별거래실적_은행', 'table1_col17': '투자자별거래실적_은행.1', 'table1_col18': '투자자별거래실적_은행.2', 'table1_col19': '투자자별거래실적_기타금융', 'table1_col20': '투자자별거래실적_기타금융.1', 'table1_col21': '투자자별거래실적_기타금융.2', 'table1_col22': '투자자별거래실적_연기금 등', 'table1_col23': '투자자별거래실적_연기금 등.1', 'table1_col24': '투자자별거래실적_연기금 등.2', 'table1_col25': '투자자별거래실적_기관합계', 'table1_col26': '투자자별거래실적_기관합계.1', 'table1_col27': '투자자별거래실적_기관합계.2', 'table1_col28': '투자자별거래실적_기타법인', 'table1_col29': '투자자별거래실적_기타법인.1', 'table1_col30': '투자자별거래실적_기타법인.2', 'table1_col31': '투자자별거래실적_개인', 'table1_col32': '투자자별거래실적_개인.1', 'table1_col33': '투자자별거래실적_개인.2', 'table1_col34': '투자자별거래실적_외국인', 'table1_col35': '투자자별거래실적_외국인.1', 'table1_col36': '투자자별거래실적_외국인.2', 'table1_col37': '투자자별거래실적_기타외국인', 'table1_col38': '투자자별거래실적_기타외국인.1', 'table1_col39': '투자자별거래실적_기타외국인.2', 'table1_col40': '투자자별거래실적_총거래대금', 'table1_col41': '투자자별거래실적_총거래대금.1', 'table1_col42': '투자자별거래실적_총거래대금.2', 'table1_col43': '투자자별거래실적_금융투자.3', 'table1_col44': '투자자별거래실적_금융투자.4', 'table1_col45': '투자자별거래실적_금융투자.5', 'table1_col46': '투자자별거래실적_보험.3', 'table1_col47': '투자자별거래실적_보험.4', 'table1_col48': '투자자별거래실적_보험.5', 'table1_col49': '투자자별거래실적_투신.3', 'table1_col50': '투자자별거래실적_투신.4', 'table1_col51': '투자자별거래실적_투신.5', 'table1_col52': '투자자별거래실적_사모.3', 'table1_col53': '투자자별거래실적_사모.4', 'table1_col54': '투자자별거래실적_사모.5', 'table1_col55': '투자자별거래실적_은행.3', 'table1_col56': '투자자별거래실적_은행.4', 'table1_col57': '투자자별거래실적_은행.5', 'table1_col58': '투자자별거래실적_기타금융.3', 'table1_col59': '투자자별거래실적_기타금융.4', 'table1_col60': '투자자별거래실적_기타금융.5', 'table1_col61': '투자자별거래실적_연기금 등.3', 'table1_col62': '투자자별거래실적_연기금 등.4', 'table1_col63': '투자자별거래실적_연기금 등.5', 'table1_col64': '투자자별거래실적_기관합계.3', 'table1_col65': '투자자별거래실적_기관합계.4', 'table1_col66': '투자자별거래실적_기관합계.5', 'table1_col67': '투자자별거래실적_기타법인.3', 'table1_col68': '투자자별거래실적_기타법인.4', 'table1_col69': '투자자별거래실적_기타법인.5', 'table1_col70': '투자자별거래실적_개인.3', 'table1_col71': '투자자별거래실적_개인.4', 'table1_col72': '투자자별거래실적_개인.5', 'table1_col73': '투자자별거래실적_외국인.3', 'table1_col74': '투자자별거래실적_외국인.4', 'table1_col75': '투자자별거래실적_외국인.5', 'table1_col76': '투자자별거래실적_기타외국인.3', 'table1_col77': '투자자별거래실적_기타외국인.4', 'table1_col78': '투자자별거래실적_기타외국인.5', 'table2_date': '거래실적_시점', 'table2_col1': '거래실적_매매일수 (일)', 'table2_col2': '거래실적_거래량', 'table2_col3': '거래실적_거래량.1', 'table2_col4': '거래실적_거래량.2', 'table2_col5': '거래실적_거래량.3', 'table2_col6': '거래실적_거래량.4', 'table2_col7': '거래실적_거래량.5', 'table2_col8': '거래실적_거래량.6', 'table2_col9': '거래실적_거래량.7', 'table2_col10': '거래실적_거래대금', 'table2_col11': '거래실적_거래대금.1', 'table2_col12': '거래실적_거래대금.2', 'table2_col13': '거래실적_거래대금.3', 'table2_col14': '거래실적_거래대금.4', 'table2_col15': '거래실적_거래대금.5', 'table2_col16': '거래실적_거래대금.6', 'table2_col17': '거래실적_거래대금.7', 'table3_date': '투자자별거래실적_시점', 'table3_col1': '투자자별거래실적_총거래량', 'table3_col2': '투자자별거래실적_총거래량.1', 'table3_col3': '투자자별거래실적_총거래량.2', 'table3_col4': '투자자별거래실적_금융투자', 'table3_col5': '투자자별거래실적_금융투자.1', 'table3_col6': '투자자별거래실적_금융투자.2', 'table3_col7': '투자자별거래실적_보험', ...
